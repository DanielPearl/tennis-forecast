# %% [markdown]
# # 03 — Backtest
#
# Replay the held-out window with the trained model and inspect ROI / drawdown / cohort splits.

# %%
import sys, pathlib, json
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.trading.backtest import run_backtest
metrics = run_backtest()
print(json.dumps({k: v for k, v in metrics.items() if not isinstance(v, list)}, indent=2, default=str))
