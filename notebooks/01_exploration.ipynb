# %% [markdown]
# # 01 — Exploration
#
# Pull the Sackmann match panel and poke at it. Useful for spotting bad rows / column-type issues before training.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.data.fetch_matches import fetch_all
df = fetch_all()
print(df.shape)
df.head()

# %%
# Surface distribution and missing-rate quick check
df.groupby(['tour','surface']).size().unstack(fill_value=0)
