# %% [markdown]
# # 02 — Train the pre-match model
#
# End-to-end: fetch ⇒ feature panel ⇒ train ⇒ persist artifacts. See `src/models/train_prematch_model.py` for the code; this notebook just calls it and inspects the metrics.

# %%
import sys, pathlib, json
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.models.train_prematch_model import train_and_persist
metrics = train_and_persist()
print(json.dumps(metrics, indent=2))
